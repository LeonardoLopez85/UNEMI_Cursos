# %% [markdown]
# <a href="https://colab.research.google.com/github/crodriguezn/python-2025/blob/master/U3_Tema_1_Clases%2C_Herencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase básica

# %%
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def presentarse(self):
        return f"Soy {self.nombre} y tengo {self.edad} años."


persona = Persona("Juan", 25)
print(persona.presentarse())
# Out:
# Soy Juan y tengo 25 años.

# %% [markdown]
# # Herencia

# %%
class Estudiante(Persona):
    def __init__(self, nombre, edad, curso):
        super().__init__(nombre, edad)
        self.curso = curso

    def presentarse(self):
        return f"Soy {self.nombre}, tengo {self.edad} años y estudio {self.curso}."

estudiante = Estudiante("Ana", 20, "Matemáticas")
print(estudiante.presentarse())
# Out:
# Soy Ana, tengo 20 años y estudio Matemáticas.

# %%
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

    def presentarse(self):
        return f"Soy {self.nombre} y tengo {self.edad} años."


persona = Persona("Juan", 25)
print(persona.presentarse())


class Estudiante(Persona):
    def __init__(self, nombre, edad, curso):
        super().__init__(nombre, edad)
        self.curso = curso

    def presentarse(self):
        return f"Soy {self.nombre}, tengo {self.edad} años y estudio {self.curso}."

estudiante = Estudiante("Ana", 20, "Matemáticas")
print(estudiante.presentarse())

persona1 = Persona("Luisa", 30)
estudiante1 = Estudiante("Jorge", 20, "Python")

print(persona1.presentarse())
print(estudiante1.presentarse())
# Out:
# Soy Juan y tengo 25 años.
# Soy Ana, tengo 20 años y estudio Matemáticas.
# Soy Luisa y tengo 30 años.
# Soy Jorge, tengo 20 años y estudio Python.
